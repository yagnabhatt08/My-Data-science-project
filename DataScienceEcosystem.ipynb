# %%
# Exercise-2 - Create markdown cell with title of the notebook

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # Data Science Tools and Ecosystem

# %%
# Exercise-3 - Create a markdown cell for an introduction

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %%
# Exercise-10 - Insert a markdown cell to list Objectives

# %% [markdown]
# __Objectives:__

# %% [markdown]
# __Objectives:__

# %% [markdown]
# - List Data Science Languages
# - List Data Science Libraries
# - List Data Science Tools
# - Introduction to Basic Arithematic Operations
# - Coversion of Minutes to Hours using basic mathematical operations

# %% [markdown]
# - List Data Science Languages
# - List Data Science Libraries
# - List Data Science Tools
# - Introduction to Basic Arithematic Operations
# - Coversion of Minutes to Hours using basic mathematical operations

# %%
# Exercise-4 - Create a markdown cell to list data science languages

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R Programming
# 3. SQL - Structured Query Language
# 4. Java
# 5. Julia

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R Programming
# 3. SQL - Structured Query Language
# 4. Java
# 5. Julia

# %%
# Exercise-5 - Create a markdown cell to list data science libraries

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Plotly
# 4. dplyr
# 5. caret

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Plotly
# 4. dplyr
# 5. caret

# %%
# Exercise-6 - Create a markdown cell with a table of Data Science tools

# %% [markdown]
# | _*Data Science Tools*_ |
# | ---------------------- |
# | JupyterLab |
# | Virtual Studio Code (VS Code) |
# | Rstudio |

# %% [markdown]
# | _*Data Science Tools*_ |
# | ---------------------- |
# | JupyterLab |
# | Virtual Studio Code (VS Code) |
# | Rstudio |

# %%
# Exercise-7 - Create a markdown cell introducing arithmetic expression examples

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# .

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# .

# %%
# Exercise-8 - Create a code cell to multiply and add numbers

# %% [markdown]
# _This a simple arithmetic expression to mutiply then add integers._

# %% [markdown]
# _This a simple arithmetic expression to mutiply then add integers._

# %%
(3*4)+5
# Out:
# 17

# %%
# Exercise-9 - Create a code cell to convert minutes to hours

# %% [markdown]
# _This will convert 200 minutes to hours by diving by 60_

# %% [markdown]
# _This will convert 200 minutes to hours by diving by 60_

# %%
200/60
# Out:
# 3.3333333333333335

# %%
# Exercise-11 - Create a markdown cell to indicate the Author's name

# %% [markdown]
# ## Author ##
# Yagna

# %% [markdown]
# ## Author ##
# Yagna
